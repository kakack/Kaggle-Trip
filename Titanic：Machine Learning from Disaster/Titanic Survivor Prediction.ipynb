# %%
import pandas as pd
import numpy as np
from pandas import Series,DataFrame

train_orig = pd.read_csv("./dataset/train.csv")
train_orig
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
train_orig.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
train_orig.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
import raw_Data_plot as rdp
rdp.raw_Data_plot(train_orig)

# %%
import raw_Data_plot_2 as rdp2
rdp2.raw_Data_plot_2(train_orig)

# %%
import Set_Attribution as sa
data_train, rfr = sa.set_missing_ages(train_orig)
data_train = sa.set_Cabin_type(data_train)
data_train = sa.set_Sex_type(data_train)
data_train = sa.set_Embarked_type(data_train)
data_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
# data_train.describe()
# data_train.info()
from sklearn import linear_model

train_df = data_train.filter(regex='Survived|Age|SibSp|Parch|Fare|Cabin|Embarked|Sex|Pclass')
train_np = train_df.as_matrix()

y = train_np[:, 0]
X = train_np[:, 1:]

clf = linear_model.LogisticRegression(C=1.0, penalty='l1', tol=1e-6)
clf.fit(X, y)
    
clf
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l1', random_state=None, solver='liblinear', tol=1e-06,
#           verbose=0, warm_start=False)

# %%
X.shape
# Out:
# (891, 8)

# %%
test_orig = pd.read_csv("./dataset/test.csv")
test_orig.loc[ (test_orig.Fare.isnull()), 'Fare' ] = 0

tmp_df = test_orig[['Age','Fare', 'Parch', 'SibSp', 'Pclass']]
null_age = tmp_df[test_orig.Age.isnull()].as_matrix()

X = null_age[:, 1:]
predictedAges = rfr.predict(X)
test_orig.loc[ (test_orig.Age.isnull()), 'Age' ] = predictedAges

data_test = sa.set_Cabin_type(test_orig)
data_test = sa.set_Sex_type(data_test)
data_test = sa.set_Embarked_type(data_test)
data_test
# Out:
#      PassengerId  Pclass                                               Name  \
# 0            892       3                                   Kelly, Mr. James
# 1            893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                          Myles, Mr. Thomas Francis
# 3            895       3                                   Wirz, Mr. Albert
# 4            896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                         Svensson, Mr. Johan Cervin
# 6            898       3                               Connolly, Miss. Kate
# 7            899       2                       Caldwell, Mr. Albert Francis
# 8            900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9            901       3                            Davies, Mr. John Samuel
# 10           902       3                                   Ilieff, Mr. Ylio
# ...

# %%
test = data_test.filter(regex='Survived|Age|SibSp|Parch|Fare|Cabin|Embarked|Sex|Pclass')
predictions = clf.predict(test)
result = pd.DataFrame({'PassengerId':data_test['PassengerId'].as_matrix(), 'Survived':predictions.astype(np.int32)})
result.to_csv("./output/logistic_regression_predictions.csv", index=False)

# %%
pd.read_csv("./output/logistic_regression_predictions.csv")
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         1
# 5            897         0
# 6            898         1
# 7            899         0
# 8            900         1
# 9            901         0
# 10           902         0
# 11           903         0
# 12           904         1
# 13           905         0
# 14           906         1
# 15           907         1
# 16           908         0
# 17           909         0
# 18           910         1
# 19           911         1
# 20           912         0
# 21           913         0
# 22           914         1
# 23           915         1
# 24           916         1
# 25           917         0
# 26           918         1
# 27           919         0
# 28           920         0
# 29           921         0
# ..           ...       ...
# 388         1280         0
# 389         1281         0
# ...

# %%
pd.DataFrame({"columns":list(train_df.columns)[1:], "coef":list(clf.coef_.T)})
# Out:
#                  coef   columns
# 0   [-0.848906281303]    Pclass
# 1     [1.33841760351]       Sex
# 2  [-0.0382503120865]       Age
# 3   [-0.356515264407]     SibSp
# 4   [-0.102585541187]     Parch
# 5  [0.00160977813372]      Fare
# 6    [0.354064739695]     Cabin
# 7   [-0.161546033949]  Embarked

# %%
from sklearn.model_selection import cross_val_predict
from sklearn import linear_model
import matplotlib.pyplot as plt


clf = linear_model.LogisticRegression()
all_data = data_train.filter(regex='Survived|Pclass|Sex|Age|SibSp|Parch|Fare|Cabin|Embarked')
print(all_data)
X = all_data.as_matrix()[:, 1:]
y = all_data.as_matrix()[:,0]
predicted = cross_val_predict(clf, X, y, cv=10)

fig, ax = plt.subplots()
ax.scatter(y, predicted, edgecolors=(0, 0, 0))
ax.plot([y.min(), y.max()], [y.min(), y.max()], 'k--', lw=4)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
plt.show()
# Out:
#      Survived  Pclass  Sex        Age  SibSp  Parch      Fare  Cabin  Embarked
# 0           0       3   -1  22.000000      1      0    7.2500     -1         3
# 1           1       1    1  38.000000      1      0   71.2833      1         1
# 2           1       3    1  26.000000      0      0    7.9250     -1         3
# 3           1       1    1  35.000000      1      0   53.1000      1         3
# 4           0       3   -1  35.000000      0      0    8.0500     -1         3
# 5           0       3   -1  23.838953      0      0    8.4583     -1         2
# 6           0       1   -1  54.000000      0      0   51.8625      1         3
# 7           0       3   -1   2.000000      3      1   21.0750     -1         3
# 8           1       3    1  27.000000      0      2   11.1333     -1         3
# 9           1       2    1  14.000000      1      0   30.0708     -1         1
# 10          1       3    1   4.000000      1      1   16.7000      1         3
# ...
